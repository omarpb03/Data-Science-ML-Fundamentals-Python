# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
#df = pd.read_csv
#df.shape
#df.head

# %% [markdown]
# arbol_gini.predict() <- se utiliza para obtener la predicción de la clase o valor de respuesta para un nuevo conjunto de datos de entrada, basándose en un modelo de Árbol de Decisión previamente entrenado.

# %% [markdown]
# tree.plot_tree <- se utiliza para visualizar gráficamente un modelo de Árbol de Decisión previamente entrenado.
#
# En esencia, toma el modelo entrenado y lo transforma en un diagrama de flujo fácil de entender, lo que convierte al Árbol de Decisión en un modelo de "caja blanca" (white box model), ya que permite ver y comprender todas las reglas que el algoritmo utiliza para tomar una predicción.

# %% [markdown]
# gini =0.0 <- no hay proba de que X[] <= algo

# %% [markdown]
# ## Criterion entropy

# %% [markdown]
# entropy.predict <=El método .predict() aplicado a un modelo de Árbol de Decisión (ya sea clasificador o regresor) realiza la tarea fundamental de generar predicciones para un nuevo conjunto de datos de entrada.

# %% [markdown]
# entropy <- grado de incertidumbre, desorden o impureza en un conjunto de datos.

# %% [markdown]
# weighted average <- un tipo de promedio que calcula las métricas (precisión, recall y puntuación F1) para todas las clases, pero ponderando la contribución de cada clase por su soporte (la cantidad de instancias reales de esa clase en el conjunto de datos).
